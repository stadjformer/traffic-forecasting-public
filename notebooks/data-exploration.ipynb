# %% [markdown]
# # Initial data exploration

# %%
from pprint import pprint

from dotenv import load_dotenv

if not load_dotenv(".env_jupyter"):
    raise RuntimeError("specified .env file not found")

import utils

# %% [markdown]
# ## METR-LA

# %%
ds = utils.io.get_dataset_hf("METR-LA")
pprint(ds)
pprint(ds["train"].features)

# %%
A, distances, locations = utils.io.get_graph_metadata("METR-LA")
print("Adjacency matrix")
pprint(A)
print("Sensor distances")
pprint(distances.head(5))
print("...\n")
print("Sensor locations")
pprint(locations.head(5))
print("...\n")
utils.visual.sensor_locations(locations)

# %% [markdown]
# ## PEMS-BAY

# %%
ds = utils.io.get_dataset_hf("PEMS-BAY")
pprint(ds)
pprint(ds["train"].features)

# %%
A, distances, locations = utils.io.get_graph_metadata("PEMS-BAY")
print("Adjacency matrix")
pprint(A)
print("Sensor distances")
pprint(distances.head(5))
print("...\n")
print("Sensor locations")
pprint(locations.head(5))
print("...\n")
utils.visual.sensor_locations(locations)
